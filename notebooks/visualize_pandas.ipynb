# %%
# -*- coding: utf-8 -*-
"""
Created on Sat Oct  6 17:26:51 2018

@author: Kevin
"""

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

pd.options.mode.chained_assignment = None  # default='warn', Mutes warnings when copying a slice from a DataFrame.

# %%
DATA_TRAIN_PATH = '../data/train.csv'
data = pd.read_csv(DATA_TRAIN_PATH)

# %%
DATA_TEST_PATH = '../data/test.csv'
data_test = pd.read_csv(DATA_TEST_PATH)
print(data.shape)
# Out:
# (250000, 32)

# %%
data_test.describe()
# Out:
#                   Id   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  568238.000000  568238.000000                568238.000000
# mean   634118.500000     -48.729241                    49.258387
# std    164036.325469     406.018702                    35.393465
# min    350000.000000    -999.000000                     0.000000
# 25%    492059.250000      78.191000                    19.330000
# 50%    634118.500000     105.080000                    46.467000
# 75%    776177.750000     130.775500                    73.630000
# max    918237.000000    1949.261000                   968.669000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  568238.000000  568238.000000         568238.000000     568238.000000
# mean       81.122338      57.829094           -707.441800       -599.731058
# std        40.474035      63.304450            454.931763        659.054554
# ...

# %%
data.describe()
# Out:
#                   Id   DER_mass_MMC  DER_mass_transverse_met_lep  \
# count  250000.000000  250000.000000                250000.000000
# mean   224999.500000     -49.023079                    49.239819
# std     72168.927986     406.345647                    35.344886
# min    100000.000000    -999.000000                     0.000000
# 25%    162499.750000      78.100750                    19.241000
# 50%    224999.500000     105.012000                    46.524000
# 75%    287499.250000     130.606250                    73.598000
# max    349999.000000    1192.026000                   690.075000
#
#         DER_mass_vis       DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  250000.000000  250000.000000         250000.000000     250000.000000
# mean       81.181982      57.895962           -708.420675       -601.237051
# std        40.828691      63.655682            454.480565        657.972302
# ...

# %%
print("Differents columns attributes : \n")

for i in data:
    print(i)
    
print("\nShape : " + str(data.shape))
# Out:
# Differents columns attributes :
#
# Id
# Prediction
# DER_mass_MMC
# DER_mass_transverse_met_lep
# DER_mass_vis
# DER_pt_h
# DER_deltaeta_jet_jet
# DER_mass_jet_jet
# DER_prodeta_jet_jet
# DER_deltar_tau_lep
# DER_pt_tot
# DER_sum_pt
# DER_pt_ratio_lep_tau
# DER_met_phi_centrality
# DER_lep_eta_centrality
# PRI_tau_pt
# PRI_tau_eta
# PRI_tau_phi
# PRI_lep_pt
# PRI_lep_eta
# PRI_lep_phi
# PRI_met
# PRI_met_phi
# PRI_met_sumet
# PRI_jet_num
# PRI_jet_leading_pt
# PRI_jet_leading_eta
# PRI_jet_leading_phi
# PRI_jet_subleading_pt
# PRI_jet_subleading_eta
# PRI_jet_subleading_phi
# PRI_jet_all_pt
#
# Shape : (250000, 32)

# %%
data['PRI_jet_num'].hist()

# %%
data_jet0 = data[data['PRI_jet_num'] == 0]
print("\nShape datajet0 : "+ str(data_jet0.shape))

data_jet1 = data[data['PRI_jet_num'] == 1]
print("\nShape datajet1 : "+ str(data_jet1.shape))

data_jet2 = data[data['PRI_jet_num'] == 2]
print("\nShape datajet2 : "+ str(data_jet2.shape))

data_jet3 = data[data['PRI_jet_num'] == 3]
print("\nShape datajet3 : "+ str(data_jet3.shape))
# Out:
# Shape datajet0 : (99913, 32)
#
# Shape datajet1 : (77544, 32)
#
# Shape datajet2 : (50379, 32)
#
# Shape datajet3 : (22164, 32)

# %%
data_jet1.describe()
# Out:
#                   Id  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# count   77544.000000  77544.000000                  77544.00000  77544.000000
# mean   225144.066040     12.845744                     46.05360     82.219033
# std     72137.275981    337.359355                     35.58119     42.288122
# min    100001.000000   -999.000000                      0.00000      6.329000
# 25%    162817.750000     84.531750                     16.26750     59.809750
# 50%    225049.500000    107.934500                     40.49850     73.936000
# 75%    287516.500000    132.932500                     70.01300     92.679750
# max    349997.000000   1192.026000                    571.86800    959.601000
#
#            DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  77544.000000               77544.0           77544.0
# mean      65.903090                -999.0            -999.0
# std       47.431007                   0.0               0.0
# ...

# %%
data_jet2.describe()
# Out:
#                   Id  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# count   50379.000000  50379.000000                 50379.000000  50379.000000
# mean   225129.697374     56.928924                    38.343612     79.213348
# std     72182.186996    268.937491                    35.273944     39.917128
# min    100000.000000   -999.000000                     0.000000      7.330000
# 25%    162596.500000     91.593500                    11.605500     58.525000
# 50%    225414.000000    112.991000                    28.501000     72.270000
# 75%    287655.500000    132.447500                    56.512000     89.505500
# max    349994.000000    966.986000                   595.819000   1051.358000
#
#            DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  50379.000000          50379.000000      50379.000000
# mean     102.985028              2.606534        391.406450
# std       70.529284              1.812621        426.852418
# ...

# %%
data_jet3.describe()
# Out:
#                   Id  DER_mass_MMC  DER_mass_transverse_met_lep  DER_mass_vis  \
# count   22164.000000  22164.000000                 22164.000000  22164.000000
# mean   224679.896003     48.407703                    42.120203     78.925522
# std     72390.704166    288.136803                    38.075038     48.790879
# min    100005.000000   -999.000000                     0.000000     10.342000
# 25%    161858.000000     84.995500                    13.425750     54.037250
# 50%    224412.500000    104.558500                    32.165000     67.991000
# 75%    287699.750000    130.189750                    62.188000     87.763250
# max    349993.000000    988.199000                   690.075000   1329.913000
#
#            DER_pt_h  DER_deltaeta_jet_jet  DER_mass_jet_jet  \
# count  22164.000000          22164.000000      22164.000000
# mean     126.066343              1.942770        327.179877
# std       83.821859              1.469926        317.279844
# ...

# %%
val = 0
for i in data_jet0:
    val = val +data_jet0[data_jet0[i] == -999.000][i].count()
    print(str(i) + '  : ' + str(data_jet0[data_jet0[i] == -999.000][i].count()))


print("\n\n Total -999.000 wrong values : " + str(val))
print("\nSize of data_jet0" + str(data_jet0.shape))
# Out:
# Id  : 0
# Prediction  : 0
# DER_mass_MMC  : 26123
# DER_mass_transverse_met_lep  : 0
# DER_mass_vis  : 0
# DER_pt_h  : 0
# DER_deltaeta_jet_jet  : 99913
# DER_mass_jet_jet  : 99913
# DER_prodeta_jet_jet  : 99913
# DER_deltar_tau_lep  : 0
# DER_pt_tot  : 0
# DER_sum_pt  : 0
# DER_pt_ratio_lep_tau  : 0
# DER_met_phi_centrality  : 0
# DER_lep_eta_centrality  : 99913
# PRI_tau_pt  : 0
# PRI_tau_eta  : 0
# PRI_tau_phi  : 0
# PRI_lep_pt  : 0
# PRI_lep_eta  : 0
# PRI_lep_phi  : 0
# PRI_met  : 0
# PRI_met_phi  : 0
# PRI_met_sumet  : 0
# PRI_jet_num  : 0
# PRI_jet_leading_pt  : 99913
# PRI_jet_leading_eta  : 99913
# PRI_jet_leading_phi  : 99913
# PRI_jet_subleading_pt  : 99913
# PRI_jet_subleading_eta  : 99913
# PRI_jet_subleading_phi  : 99913
# PRI_jet_all_pt  : 0
#
#
#  Total -999.000 wrong values : 1025253
#
# Size of data_jet0(99913, 32)

# %%
val = 0
for i in data_jet1:
    val = val +data_jet1[data_jet1[i] == -999.000][i].count()
    print(str(i) + '  : ' + str(data_jet1[data_jet1[i] == -999.000][i].count()))


print("\n\n Total -999.000 wrong values : " + str(val))
print("\nSize of data_jet1" + str(data_jet1.shape))
# Out:
# Id  : 0
# Prediction  : 0
# DER_mass_MMC  : 7562
# DER_mass_transverse_met_lep  : 0
# DER_mass_vis  : 0
# DER_pt_h  : 0
# DER_deltaeta_jet_jet  : 77544
# DER_mass_jet_jet  : 77544
# DER_prodeta_jet_jet  : 77544
# DER_deltar_tau_lep  : 0
# DER_pt_tot  : 0
# DER_sum_pt  : 0
# DER_pt_ratio_lep_tau  : 0
# DER_met_phi_centrality  : 0
# DER_lep_eta_centrality  : 77544
# PRI_tau_pt  : 0
# PRI_tau_eta  : 0
# PRI_tau_phi  : 0
# PRI_lep_pt  : 0
# PRI_lep_eta  : 0
# PRI_lep_phi  : 0
# PRI_met  : 0
# PRI_met_phi  : 0
# PRI_met_sumet  : 0
# PRI_jet_num  : 0
# PRI_jet_leading_pt  : 0
# PRI_jet_leading_eta  : 0
# PRI_jet_leading_phi  : 0
# PRI_jet_subleading_pt  : 77544
# PRI_jet_subleading_eta  : 77544
# PRI_jet_subleading_phi  : 77544
# PRI_jet_all_pt  : 0
#
#
#  Total -999.000 wrong values : 550370
#
# Size of data_jet1(77544, 32)

# %%
val = 0
for i in data_jet2:
    val = val +data_jet2[data_jet2[i] == -999.000][i].count()
    print(str(i) + '  : ' + str(data_jet2[data_jet2[i] == -999.000][i].count()))


print("\n\n Total -999.000 wrong values : " + str(val))
print("\nSize of data_jet2" + str(data_jet2.shape))
# Out:
# Id  : 0
# Prediction  : 0
# DER_mass_MMC  : 2952
# DER_mass_transverse_met_lep  : 0
# DER_mass_vis  : 0
# DER_pt_h  : 0
# DER_deltaeta_jet_jet  : 0
# DER_mass_jet_jet  : 0
# DER_prodeta_jet_jet  : 0
# DER_deltar_tau_lep  : 0
# DER_pt_tot  : 0
# DER_sum_pt  : 0
# DER_pt_ratio_lep_tau  : 0
# DER_met_phi_centrality  : 0
# DER_lep_eta_centrality  : 0
# PRI_tau_pt  : 0
# PRI_tau_eta  : 0
# PRI_tau_phi  : 0
# PRI_lep_pt  : 0
# PRI_lep_eta  : 0
# PRI_lep_phi  : 0
# PRI_met  : 0
# PRI_met_phi  : 0
# PRI_met_sumet  : 0
# PRI_jet_num  : 0
# PRI_jet_leading_pt  : 0
# PRI_jet_leading_eta  : 0
# PRI_jet_leading_phi  : 0
# PRI_jet_subleading_pt  : 0
# PRI_jet_subleading_eta  : 0
# PRI_jet_subleading_phi  : 0
# PRI_jet_all_pt  : 0
#
#
#  Total -999.000 wrong values : 2952
#
# Size of data_jet2(50379, 32)

# %%
val = 0
for i in data_jet3:
    val = val +data_jet3[data_jet3[i] == -999.000][i].count()
    print(str(i) + '  : ' + str(data_jet3[data_jet3[i] == -999.000][i].count()))


print("\n\n Total -999.000 wrong values : " + str(val))
print("\nSize of data_jet3" + str(data_jet3.shape))
# Out:
# Id  : 0
# Prediction  : 0
# DER_mass_MMC  : 1477
# DER_mass_transverse_met_lep  : 0
# DER_mass_vis  : 0
# DER_pt_h  : 0
# DER_deltaeta_jet_jet  : 0
# DER_mass_jet_jet  : 0
# DER_prodeta_jet_jet  : 0
# DER_deltar_tau_lep  : 0
# DER_pt_tot  : 0
# DER_sum_pt  : 0
# DER_pt_ratio_lep_tau  : 0
# DER_met_phi_centrality  : 0
# DER_lep_eta_centrality  : 0
# PRI_tau_pt  : 0
# PRI_tau_eta  : 0
# PRI_tau_phi  : 0
# PRI_lep_pt  : 0
# PRI_lep_eta  : 0
# PRI_lep_phi  : 0
# PRI_met  : 0
# PRI_met_phi  : 0
# PRI_met_sumet  : 0
# PRI_jet_num  : 0
# PRI_jet_leading_pt  : 0
# PRI_jet_leading_eta  : 0
# PRI_jet_leading_phi  : 0
# PRI_jet_subleading_pt  : 0
# PRI_jet_subleading_eta  : 0
# PRI_jet_subleading_phi  : 0
# PRI_jet_all_pt  : 0
#
#
#  Total -999.000 wrong values : 1477
#
# Size of data_jet3(22164, 32)
